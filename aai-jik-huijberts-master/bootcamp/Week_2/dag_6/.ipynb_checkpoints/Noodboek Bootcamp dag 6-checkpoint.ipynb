# %% [markdown]
# #### Importeer de juiste libraries

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import StandardScaler
from scipy import stats
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.linear_model import LinearRegression
from random import sample

# %matplotlib inline

# %% [markdown]
# #### Laad en bekijk de data

# %%
data = pd.read_csv('airlinesatisfaction.csv')

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'id',
#  'Gender',
#  'Customer Type',
#  'Age',
#  'Type of Travel',
#  'Class',
#  'Flight Distance',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'satisfaction']

# %% [markdown]
# Verwijder de kolommen waarvan de titel niet aangeeft wat de feature betekent.

# %%
data = data.drop(columns = ["Unnamed: 0",
 "id"], axis=1)

# %%
list(data.columns)
# Out:
# ['Gender',
#  'Customer Type',
#  'Age',
#  'Type of Travel',
#  'Class',
#  'Flight Distance',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'satisfaction']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
#  11  Online boarding                    103904 non-null  int64
#  12  Seat comfort                       103904 non-null  int64
#  13  Inflight entertainment             103904 non-null  int64
#  14  On-board service                   103904 non-null  int64
#  15  Leg room service                   103904 non-null  int64
#  16  Baggage handling                   103904 non-null  int64
#  17  Checkin service                    103904 non-null  int64
#  18  Inflight service                   103904 non-null  int64
#  19  Cleanliness                        103904 non-null  int64
#  20  Departure Delay in Minutes         103904 non-null  int64
#  21  Arrival Delay in Minutes           103594 non-null  float64
#  22  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 18.2+ MB

# %%
#We dienen voordat we normaliseren de nominale en eventuele ordinale schalen om te zetten in cijfers
data['satisfaction'].replace({'neutral or dissatisfied': 0, 'satisfied': 1},inplace = True)
data['Gender'].replace({'Male': 0, 'Female': 1}, inplace = True)
data['Customer Type'].replace({'disloyal Customer': 0, 'Loyal Customer': 1}, inplace = True)
data['Type of Travel'].replace({'Personal Travel': 0, 'Business travel': 1}, inplace = True)
data['Class'].replace({'Eco': 1, 'Eco Plus': 2, 'Business':3}, inplace = True)

# %% [markdown]
# #### Plot histogrammen

# %%
# Als je alle data tegelijk wil plotten:
data.hist(bins = 20, figsize = (20,10))
# Als je maar 1 variabele wil plotten
data.hist(column = "Age", bins = 20)
data.hist(column = "Flight Distance", bins = 30)
data.hist(column = "Departure Delay in Minutes", bins = 10)
# Out:
# array([[<AxesSubplot:title={'center':'Departure Delay in Minutes'}>]],
#       dtype=object)

# %%
#Tijd voor de boxplotten
import seaborn as sns
sns.boxplot(x=data['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x=data['Flight Distance'])
# Out:
# <AxesSubplot:xlabel='Flight Distance'>

# %%
sns.boxplot(x=data['Departure Delay in Minutes'])
# Out:
# <AxesSubplot:xlabel='Departure Delay in Minutes'>

# %%
sns.boxplot(x=data['Arrival Delay in Minutes'])
# Out:
# <AxesSubplot:xlabel='Arrival Delay in Minutes'>

# %% [markdown]
# #### Check of de data normaal verdeeld is met Shapiro-Wilk

# %%
#Je kan dit voor elke feature doen.
test = stats.shapiro(data.Age)


    
print(test.pvalue)
# Out:
# 0.0
# D:\anaconda\lib\site-packages\scipy\stats\morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
#Het kan ook met Kolmogorov Smirnov
stats.kstest(data['Age'], stats.norm.cdf)
# Out:
# KstestResult(statistic=0.9999999999987201, pvalue=0.0)

# %% [markdown]
# #### Zet de features om in z-scores (normaliseren)

# %%
print(data[0:5])
scaler = StandardScaler()
data_z = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)
print(data_z[0:5])
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              1   13               0      2              460
# 1       0              0   25               1      3              235
# 2       1              1   26               1      3             1142
# 3       1              1   25               1      3              562
# 4       0              1   61               1      3              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]
#      Gender  Customer Type       Age  Type of Travel     Class  \
# 0 -1.015031       0.472767 -1.745279       -1.490614 -0.029187
# 1 -1.015031      -2.115208 -0.951360        0.670865  1.009393
# 2  0.985192       0.472767 -0.885200        0.670865  1.009393
# 3  0.985192       0.472767 -0.951360        0.670865  1.009393
# 4 -1.015031       0.472767  1.430397        0.670865  1.009393
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0        -0.731539               0.203579                           0.616172
# 1        -0.957184               0.203579                          -0.695245
# 2        -0.047584              -0.549533                          -0.695245
# 3        -0.629246              -0.549533                           1.271880
# 4        -0.978244               0.203579                          -0.039537
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                0.173776      -1.547323  ...                1.231704
# 1                0.173776       0.018094  ...               -1.769081
# 2               -0.541060      -0.764614  ...                1.231704
# 3                1.603448       1.583511  ...               -1.018885
# 4                0.173776       0.018094  ...               -0.268688
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0          0.479403          -0.26684          0.311769         0.549799
# 1         -1.849161           1.25338         -0.535045        -1.821012
# 2          0.479403          -0.26684          0.311769         0.549799
# 3         -1.072973           1.25338         -0.535045        -1.821012
# 4         -0.296785           0.49327          0.311769        -0.240472
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0          1.156436     1.305870                    0.266393
# 1          0.305848    -1.742292                   -0.361375
# 2          0.305848     1.305870                   -0.387532
# 3          0.305848    -0.980251                   -0.099805
# 4         -0.544740    -0.218211                   -0.387532
#
#    Arrival Delay in Minutes  satisfaction
# 0                  0.072905     -0.874473
# 1                 -0.237184     -0.874473
# 2                 -0.392229      1.143545
# 3                 -0.159662     -0.874473
# 4                 -0.392229      1.143545
#
# [5 rows x 23 columns]

# %%
#Nu met de z scores
# Als je alle data tegelijk wil plotten:
data_z.hist(bins = 20, figsize = (20,10))
# Als je maar 1 variabele wil plotten
data_z.hist(column = "Age", bins = 20)
data_z.hist(column = "Flight Distance", bins = 30)
data_z.hist(column = "Departure Delay in Minutes", bins = 10)
# Out:
# array([[<AxesSubplot:title={'center':'Departure Delay in Minutes'}>]],
#       dtype=object)

# %%
#Een boxplot met z scores
sns.boxplot(x=data_z['Flight Distance'])
# Out:
# <AxesSubplot:xlabel='Flight Distance'>

# %% [markdown]
# #### Maak heatmap en scatter matrix

# %%
# Heatmap
plt.figure(figsize = (15, 15))
sns.heatmap(data.corr(), annot = True, square = True)
# Out:
# <AxesSubplot:>

# %%
#Nu met z scores
# Heatmap
plt.figure(figsize = (15, 15))
sns.heatmap(data_z.corr(), annot = True, square = True)
# Out:
# <AxesSubplot:>

# %%
# Scatter matrix
attributes = ["Age", "Flight Distance", "Departure Delay in Minutes", "Arrival Delay in Minutes"]
scatter_matrix(data[attributes], figsize = (12, 8))
plt.show()

# %%
#Nu met de z scores
# Scatter matrix
attributes = ["Age", "Flight Distance", "Departure Delay in Minutes", "Arrival Delay in Minutes"]
scatter_matrix(data_z[attributes], figsize = (12, 8))
plt.show()

# %%
# Correlatie
corr_matrix = data.corr()
print(corr_matrix["Arrival Delay in Minutes"]) # Voor de correlatie met 1 variabele
#print(corr_matrix) # Voor de hele matrix
# Out:
# Gender                              -0.000396
# Customer Type                       -0.004747
# Age                                 -0.012147
# Type of Travel                       0.005683
# Class                               -0.013674
# Flight Distance                     -0.002426
# Inflight wifi service               -0.019095
# Departure/Arrival time convenient   -0.000864
# Ease of Online booking              -0.007984
# Gate location                        0.005143
# Food and drink                      -0.032524
# Online boarding                     -0.021949
# Seat comfort                        -0.029900
# Inflight entertainment              -0.030703
# On-board service                    -0.035227
# Leg room service                     0.011843
# Baggage handling                    -0.008542
# Checkin service                     -0.020369
# Inflight service                    -0.059196
# Cleanliness                         -0.015774
# Departure Delay in Minutes           0.965481
# Arrival Delay in Minutes             1.000000
# satisfaction                        -0.057582
# Name: Arrival Delay in Minutes, dtype: float64

# %%
print(corr_matrix) 
# Voor de hele matrix
# Out:
#                                      Gender  Customer Type       Age  \
# Gender                             1.000000      -0.031732 -0.008928
# Customer Type                     -0.031732       1.000000  0.281674
# Age                               -0.008928       0.281674  1.000000
# Type of Travel                     0.006909      -0.308333  0.048524
# Class                             -0.008253       0.105735  0.140565
# Flight Distance                   -0.005828       0.225200  0.099461
# Inflight wifi service             -0.008974       0.007543  0.017859
# Departure/Arrival time convenient -0.009142       0.206869  0.038125
# Ease of Online booking            -0.006951       0.019509  0.024842
# Gate location                     -0.000333      -0.006078 -0.001330
# Food and drink                    -0.005772       0.059454  0.023000
# Online boarding                    0.042260       0.189262  0.208939
# Seat comfort                       0.026502       0.159484  0.160277
# Inflight entertainment            -0.006117       0.109930  0.076444
# On-board service                  -0.008156       0.056560  0.057594
# Leg room service                  -0.031798       0.047868  0.040583
# Baggage handling                  -0.037391      -0.024723 -0.047529
# Checkin service                   -0.010563       0.032177  0.035482
# Inflight service                  -0.039410      -0.022670 -0.049427
# Cleanliness                       -0.006505       0.083613  0.053611
# Departure Delay in Minutes        -0.002935      -0.004036 -0.010152
# Arrival Delay in Minutes          -0.000396      -0.004747 -0.012147
# satisfaction                      -0.012211       0.187638  0.137167
#
#                                    Type of Travel     Class  Flight Distance  \
# Gender                                   0.006909 -0.008253        -0.005828
# Customer Type                           -0.308333  0.105735         0.225200
# Age                                      0.048524  0.140565         0.099461
# Type of Travel                           1.000000  0.545257         0.267344
# Class                                    0.545257  1.000000         0.451211
# Flight Distance                          0.267344  0.451211         1.000000
# Inflight wifi service                    0.105085  0.036279         0.007131
# Departure/Arrival time convenient       -0.259763 -0.092788        -0.020043
# Ease of Online booking                   0.133511  0.106391         0.065717
# Gate location                            0.030700  0.004150         0.004793
# Food and drink                           0.063439  0.085908         0.056994
# Online boarding                          0.224803  0.322924         0.214869
# Seat comfort                             0.124399  0.227444         0.157333
# Inflight entertainment                   0.148199  0.194366         0.128740
# On-board service                         0.056543  0.209505         0.109526
# Leg room service                         0.138803  0.204964         0.133916
# Baggage handling                         0.031321  0.160460         0.063184
# Checkin service                         -0.016751  0.151613         0.073072
# Inflight service                         0.022599  0.156353         0.057540
# Cleanliness                              0.079207  0.135818         0.093149
# Departure Delay in Minutes               0.005432 -0.009637         0.002158
# Arrival Delay in Minutes                 0.005683 -0.013674        -0.002426
# satisfaction                             0.449000  0.494471         0.298780
#
#                                    Inflight wifi service  \
# Gender                                         -0.008974
# Customer Type                                   0.007543
# Age                                             0.017859
# Type of Travel                                  0.105085
# Class                                           0.036279
# Flight Distance                                 0.007131
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.343845
# Ease of Online booking                          0.715856
# Gate location                                   0.336248
# Food and drink                                  0.134718
# Online boarding                                 0.456970
# Seat comfort                                    0.122658
# Inflight entertainment                          0.209321
# On-board service                                0.121500
# Leg room service                                0.160473
# Baggage handling                                0.120923
# Checkin service                                 0.043193
# Inflight service                                0.110441
# Cleanliness                                     0.132698
# Departure Delay in Minutes                     -0.017402
# Arrival Delay in Minutes                       -0.019095
# satisfaction                                    0.284245
#
#                                    Departure/Arrival time convenient  \
# Gender                                                     -0.009142
# Customer Type                                               0.206869
# Age                                                         0.038125
# Type of Travel                                             -0.259763
# Class                                                      -0.092788
# Flight Distance                                            -0.020043
# Inflight wifi service                                       0.343845
# Departure/Arrival time convenient                           1.000000
# Ease of Online booking                                      0.436961
# Gate location                                               0.444757
# Food and drink                                              0.004906
# Online boarding                                             0.070119
# Seat comfort                                                0.011344
# Inflight entertainment                                     -0.004861
# On-board service                                            0.068882
# Leg room service                                            0.012441
# Baggage handling                                            0.072126
# Checkin service                                             0.093333
# Inflight service                                            0.073318
# Cleanliness                                                 0.014292
# Departure Delay in Minutes                                  0.001005
# Arrival Delay in Minutes                                   -0.000864
# satisfaction                                               -0.051601
#
#                                    Ease of Online booking  Gate location  ...  \
# Gender                                          -0.006951      -0.000333  ...
# Customer Type                                    0.019509      -0.006078  ...
# Age                                              0.024842      -0.001330  ...
# Type of Travel                                   0.133511       0.030700  ...
# Class                                            0.106391       0.004150  ...
# Flight Distance                                  0.065717       0.004793  ...
# Inflight wifi service                            0.715856       0.336248  ...
# Departure/Arrival time convenient                0.436961       0.444757  ...
# Ease of Online booking                           1.000000       0.458655  ...
# Gate location                                    0.458655       1.000000  ...
# Food and drink                                   0.031873      -0.001159  ...
# Online boarding                                  0.404074       0.001688  ...
# Seat comfort                                     0.030014       0.003669  ...
# Inflight entertainment                           0.047032       0.003517  ...
# On-board service                                 0.038833      -0.028373  ...
# Leg room service                                 0.107601      -0.005873  ...
# Baggage handling                                 0.038762       0.002313  ...
# Checkin service                                  0.011081      -0.035427  ...
# Inflight service                                 0.035272       0.001681  ...
# Cleanliness                                      0.016179      -0.003830  ...
# Departure Delay in Minutes                      -0.006371       0.005467  ...
# Arrival Delay in Minutes                        -0.007984       0.005143  ...
# satisfaction                                     0.171705       0.000682  ...
#
#                                    Inflight entertainment  On-board service  \
# Gender                                          -0.006117         -0.008156
# Customer Type                                    0.109930          0.056560
# Age                                              0.076444          0.057594
# Type of Travel                                   0.148199          0.056543
# Class                                            0.194366          0.209505
# Flight Distance                                  0.128740          0.109526
# Inflight wifi service                            0.209321          0.121500
# Departure/Arrival time convenient               -0.004861          0.068882
# Ease of Online booking                           0.047032          0.038833
# Gate location                                    0.003517         -0.028373
# Food and drink                                   0.622512          0.059073
# Online boarding                                  0.285066          0.155443
# Seat comfort                                     0.610590          0.131971
# Inflight entertainment                           1.000000          0.420153
# On-board service                                 0.420153          1.000000
# Leg room service                                 0.299692          0.355495
# Baggage handling                                 0.378210          0.519134
# Checkin service                                  0.120867          0.243914
# Inflight service                                 0.404855          0.550782
# Cleanliness                                      0.691815          0.123220
# Departure Delay in Minutes                      -0.027489         -0.031569
# Arrival Delay in Minutes                        -0.030703         -0.035227
# satisfaction                                     0.398059          0.322383
#
#                                    Leg room service  Baggage handling  \
# Gender                                    -0.031798         -0.037391
# Customer Type                              0.047868         -0.024723
# Age                                        0.040583         -0.047529
# Type of Travel                             0.138803          0.031321
# Class                                      0.204964          0.160460
# Flight Distance                            0.133916          0.063184
# Inflight wifi service                      0.160473          0.120923
# Departure/Arrival time convenient          0.012441          0.072126
# Ease of Online booking                     0.107601          0.038762
# Gate location                             -0.005873          0.002313
# Food and drink                             0.032498          0.034746
# Online boarding                            0.123950          0.083280
# Seat comfort                               0.105559          0.074542
# Inflight entertainment                     0.299692          0.378210
# On-board service                           0.355495          0.519134
# Leg room service                           1.000000          0.369544
# Baggage handling                           0.369544          1.000000
# Checkin service                            0.153137          0.233122
# Inflight service                           0.368656          0.628561
# Cleanliness                                0.096370          0.095793
# Departure Delay in Minutes                 0.014363         -0.005573
# Arrival Delay in Minutes                   0.011843         -0.008542
# satisfaction                               0.313131          0.247749
#
#                                    Checkin service  Inflight service  \
# Gender                                   -0.010563         -0.039410
# Customer Type                             0.032177         -0.022670
# Age                                       0.035482         -0.049427
# Type of Travel                           -0.016751          0.022599
# Class                                     0.151613          0.156353
# Flight Distance                           0.073072          0.057540
# Inflight wifi service                     0.043193          0.110441
# Departure/Arrival time convenient         0.093333          0.073318
# Ease of Online booking                    0.011081          0.035272
# Gate location                            -0.035427          0.001681
# Food and drink                            0.087299          0.033993
# Online boarding                           0.204462          0.074573
# Seat comfort                              0.191854          0.069218
# Inflight entertainment                    0.120867          0.404855
# On-board service                          0.243914          0.550782
# Leg room service                          0.153137          0.368656
# Baggage handling                          0.233122          0.628561
# Checkin service                           1.000000          0.237197
# Inflight service                          0.237197          1.000000
# Cleanliness                               0.179583          0.088779
# Departure Delay in Minutes               -0.018453         -0.054813
# Arrival Delay in Minutes                 -0.020369         -0.059196
# satisfaction                              0.236174          0.244741
#
#                                    Cleanliness  Departure Delay in Minutes  \
# Gender                               -0.006505                   -0.002935
# Customer Type                         0.083613                   -0.004036
# Age                                   0.053611                   -0.010152
# Type of Travel                        0.079207                    0.005432
# Class                                 0.135818                   -0.009637
# Flight Distance                       0.093149                    0.002158
# Inflight wifi service                 0.132698                   -0.017402
# Departure/Arrival time convenient     0.014292                    0.001005
# Ease of Online booking                0.016179                   -0.006371
# Gate location                        -0.003830                    0.005467
# Food and drink                        0.657760                   -0.029926
# Online boarding                       0.331517                   -0.018982
# Seat comfort                          0.678534                   -0.027898
# Inflight entertainment                0.691815                   -0.027489
# On-board service                      0.123220                   -0.031569
# Leg room service                      0.096370                    0.014363
# Baggage handling                      0.095793                   -0.005573
# Checkin service                       0.179583                   -0.018453
# Inflight service                      0.088779                   -0.054813
# Cleanliness                           1.000000                   -0.014093
# Departure Delay in Minutes           -0.014093                    1.000000
# Arrival Delay in Minutes             -0.015774                    0.965481
# satisfaction                          0.305198                   -0.050494
#
#                                    Arrival Delay in Minutes  satisfaction
# Gender                                            -0.000396     -0.012211
# Customer Type                                     -0.004747      0.187638
# Age                                               -0.012147      0.137167
# Type of Travel                                     0.005683      0.449000
# Class                                             -0.013674      0.494471
# Flight Distance                                   -0.002426      0.298780
# Inflight wifi service                             -0.019095      0.284245
# Departure/Arrival time convenient                 -0.000864     -0.051601
# Ease of Online booking                            -0.007984      0.171705
# Gate location                                      0.005143      0.000682
# Food and drink                                    -0.032524      0.209936
# Online boarding                                   -0.021949      0.503557
# Seat comfort                                      -0.029900      0.349459
# Inflight entertainment                            -0.030703      0.398059
# On-board service                                  -0.035227      0.322383
# Leg room service                                   0.011843      0.313131
# Baggage handling                                  -0.008542      0.247749
# Checkin service                                   -0.020369      0.236174
# Inflight service                                  -0.059196      0.244741
# Cleanliness                                       -0.015774      0.305198
# Departure Delay in Minutes                         0.965481     -0.050494
# Arrival Delay in Minutes                           1.000000     -0.057582
# satisfaction                                      -0.057582      1.000000
#
# [23 rows x 23 columns]

# %%
#Tijd voor meer overzicht
import pingouin as pg

# %%
#Correlatie tussen alle variabelen in een tabel
data.iloc[:, 0:25].rcorr()
# Out:
#                                    Gender Customer Type     Age  \
# Gender                                  -           ***      **
# Customer Type                      -0.032             -     ***
# Age                                -0.009         0.282       -
# Type of Travel                      0.007        -0.308   0.049
# Class                              -0.008         0.106   0.141
# Flight Distance                    -0.006         0.225   0.099
# Inflight wifi service              -0.009         0.008   0.018
# Departure/Arrival time convenient  -0.009         0.207   0.038
# Ease of Online booking             -0.007          0.02   0.025
# Gate location                        -0.0        -0.006  -0.001
# Food and drink                     -0.006         0.059   0.023
# Online boarding                     0.042         0.189   0.209
# Seat comfort                        0.027         0.159    0.16
# Inflight entertainment             -0.006          0.11   0.076
# On-board service                   -0.008         0.057   0.058
# Leg room service                   -0.032         0.048   0.041
# Baggage handling                   -0.037        -0.025  -0.048
# Checkin service                    -0.011         0.032   0.035
# Inflight service                   -0.039        -0.023  -0.049
# Cleanliness                        -0.007         0.084   0.054
# Departure Delay in Minutes         -0.003        -0.004   -0.01
# Arrival Delay in Minutes             -0.0        -0.005  -0.012
# satisfaction                       -0.012         0.188   0.137
#
#                                   Type of Travel   Class Flight Distance  \
# Gender                                         *      **
# Customer Type                                ***     ***             ***
# Age                                          ***     ***             ***
# Type of Travel                                 -     ***             ***
# Class                                      0.545       -             ***
# Flight Distance                            0.267   0.451               -
# Inflight wifi service                      0.105   0.036           0.007
# Departure/Arrival time convenient          -0.26  -0.093           -0.02
# Ease of Online booking                     0.134   0.106           0.066
# Gate location                              0.031   0.004           0.005
# Food and drink                             0.063   0.086           0.057
# Online boarding                            0.225   0.323           0.215
# Seat comfort                               0.124   0.227           0.157
# Inflight entertainment                     0.148   0.194           0.129
# On-board service                           0.057    0.21            0.11
# Leg room service                           0.139   0.205           0.134
# Baggage handling                           0.031    0.16           0.063
# Checkin service                           -0.017   0.152           0.073
# Inflight service                           0.023   0.156           0.058
# Cleanliness                                0.079   0.136           0.093
# Departure Delay in Minutes                 0.005   -0.01           0.002
# Arrival Delay in Minutes                   0.006  -0.014          -0.002
# satisfaction                               0.449   0.494           0.299
#
#                                   Inflight wifi service  \
# Gender                                               **
# Customer Type                                         *
# Age                                                 ***
# Type of Travel                                      ***
# Class                                               ***
# Flight Distance                                       *
# Inflight wifi service                                 -
# Departure/Arrival time convenient                 0.344
# Ease of Online booking                            0.716
# Gate location                                     0.336
# Food and drink                                    0.135
# Online boarding                                   0.457
# Seat comfort                                      0.123
# Inflight entertainment                            0.209
# On-board service                                  0.121
# Leg room service                                   0.16
# Baggage handling                                  0.121
# Checkin service                                   0.043
# Inflight service                                   0.11
# Cleanliness                                       0.133
# Departure Delay in Minutes                       -0.017
# Arrival Delay in Minutes                         -0.019
# satisfaction                                      0.284
#
#                                   Departure/Arrival time convenient  \
# Gender                                                           **
# Customer Type                                                   ***
# Age                                                             ***
# Type of Travel                                                  ***
# Class                                                           ***
# Flight Distance                                                 ***
# Inflight wifi service                                           ***
# Departure/Arrival time convenient                                 -
# Ease of Online booking                                        0.437
# Gate location                                                 0.445
# Food and drink                                                0.005
# Online boarding                                                0.07
# Seat comfort                                                  0.011
# Inflight entertainment                                       -0.005
# On-board service                                              0.069
# Leg room service                                              0.012
# Baggage handling                                              0.072
# Checkin service                                               0.093
# Inflight service                                              0.073
# Cleanliness                                                   0.014
# Departure Delay in Minutes                                    0.001
# Arrival Delay in Minutes                                     -0.001
# satisfaction                                                 -0.052
#
#                                   Ease of Online booking Gate location  ...  \
# Gender                                                 *                ...
# Customer Type                                        ***                ...
# Age                                                  ***                ...
# Type of Travel                                       ***           ***  ...
# Class                                                ***                ...
# Flight Distance                                      ***                ...
# Inflight wifi service                                ***           ***  ...
# Departure/Arrival time convenient                    ***           ***  ...
# Ease of Online booking                                 -           ***  ...
# Gate location                                      0.459             -  ...
# Food and drink                                     0.032        -0.001  ...
# Online boarding                                    0.404         0.002  ...
# Seat comfort                                        0.03         0.004  ...
# Inflight entertainment                             0.047         0.004  ...
# On-board service                                   0.039        -0.028  ...
# Leg room service                                   0.108        -0.006  ...
# Baggage handling                                   0.039         0.002  ...
# Checkin service                                    0.011        -0.035  ...
# Inflight service                                   0.035         0.002  ...
# Cleanliness                                        0.016        -0.004  ...
# Departure Delay in Minutes                        -0.006         0.005  ...
# Arrival Delay in Minutes                          -0.008         0.005  ...
# satisfaction                                       0.172         0.001  ...
#
#                                   Inflight entertainment On-board service  \
# Gender                                                 *               **
# Customer Type                                        ***              ***
# Age                                                  ***              ***
# Type of Travel                                       ***              ***
# Class                                                ***              ***
# Flight Distance                                      ***              ***
# Inflight wifi service                                ***              ***
# Departure/Arrival time convenient                                     ***
# Ease of Online booking                               ***              ***
# Gate location                                                         ***
# Food and drink                                       ***              ***
# Online boarding                                      ***              ***
# Seat comfort                                         ***              ***
# Inflight entertainment                                 -              ***
# On-board service                                    0.42                -
# Leg room service                                     0.3            0.355
# Baggage handling                                   0.378            0.519
# Checkin service                                    0.121            0.244
# Inflight service                                   0.405            0.551
# Cleanliness                                        0.692            0.123
# Departure Delay in Minutes                        -0.027           -0.032
# Arrival Delay in Minutes                          -0.031           -0.035
# satisfaction                                       0.398            0.322
#
#                                   Leg room service Baggage handling  \
# Gender                                         ***              ***
# Customer Type                                  ***              ***
# Age                                            ***              ***
# Type of Travel                                 ***              ***
# Class                                          ***              ***
# Flight Distance                                ***              ***
# Inflight wifi service                          ***              ***
# Departure/Arrival time convenient              ***              ***
# Ease of Online booking                         ***              ***
# Gate location
# Food and drink                                 ***              ***
# Online boarding                                ***              ***
# Seat comfort                                   ***              ***
# Inflight entertainment                         ***              ***
# On-board service                               ***              ***
# Leg room service                                 -              ***
# Baggage handling                              0.37                -
# Checkin service                              0.153            0.233
# Inflight service                             0.369            0.629
# Cleanliness                                  0.096            0.096
# Departure Delay in Minutes                   0.014           -0.006
# Arrival Delay in Minutes                     0.012           -0.009
# satisfaction                                 0.313            0.248
#
#                                   Checkin service Inflight service  \
# Gender                                        ***              ***
# Customer Type                                 ***              ***
# Age                                           ***              ***
# Type of Travel                                ***              ***
# Class                                         ***              ***
# Flight Distance                               ***              ***
# Inflight wifi service                         ***              ***
# Departure/Arrival time convenient             ***              ***
# Ease of Online booking                        ***              ***
# Gate location                                 ***
# Food and drink                                ***              ***
# Online boarding                               ***              ***
# Seat comfort                                  ***              ***
# Inflight entertainment                        ***              ***
# On-board service                              ***              ***
# Leg room service                              ***              ***
# Baggage handling                              ***              ***
# Checkin service                                 -              ***
# Inflight service                            0.237                -
# Cleanliness                                  0.18            0.089
# Departure Delay in Minutes                 -0.018           -0.055
# Arrival Delay in Minutes                    -0.02           -0.059
# satisfaction                                0.236            0.245
#
#                                   Cleanliness Departure Delay in Minutes  \
# Gender                                      *
# Customer Type                             ***
# Age                                       ***                         **
# Type of Travel                            ***
# Class                                     ***                         **
# Flight Distance                           ***
# Inflight wifi service                     ***                        ***
# Departure/Arrival time convenient         ***
# Ease of Online booking                    ***                          *
# Gate location
# Food and drink                            ***                        ***
# Online boarding                           ***                        ***
# Seat comfort                              ***                        ***
# Inflight entertainment                    ***                        ***
# On-board service                          ***                        ***
# Leg room service                          ***                        ***
# Baggage handling                          ***
# Checkin service                           ***                        ***
# Inflight service                          ***                        ***
# Cleanliness                                 -                        ***
# Departure Delay in Minutes             -0.014                          -
# Arrival Delay in Minutes               -0.016                      0.965
# satisfaction                            0.305                      -0.05
#
#                                   Arrival Delay in Minutes satisfaction
# Gender                                                              ***
# Customer Type                                                       ***
# Age                                                    ***          ***
# Type of Travel                                                      ***
# Class                                                  ***          ***
# Flight Distance                                                     ***
# Inflight wifi service                                  ***          ***
# Departure/Arrival time convenient                                   ***
# Ease of Online booking                                   *          ***
# Gate location
# Food and drink                                         ***          ***
# Online boarding                                        ***          ***
# Seat comfort                                           ***          ***
# Inflight entertainment                                 ***          ***
# On-board service                                       ***          ***
# Leg room service                                       ***          ***
# Baggage handling                                        **          ***
# Checkin service                                        ***          ***
# Inflight service                                       ***          ***
# Cleanliness                                            ***          ***
# Departure Delay in Minutes                             ***          ***
# Arrival Delay in Minutes                                 -          ***
# satisfaction                                        -0.058            -
#
# [23 rows x 23 columns]

# %%
#Beperking van aantal variabelen met nu ook de p waardes in de tabel
#Bepaal het significantie niveau (p waardes)
#Onder de diagonaal de r waardes; boven de diagonaal de p waardes
data.iloc[:, [0,1,2,5,20,21]].rcorr(stars=False, decimals=3)
# Out:
#                             Gender Customer Type     Age Flight Distance  \
# Gender                           -         0.000   0.004           0.060
# Customer Type               -0.032             -      0.              0.
# Age                         -0.009         0.282       -           0.000
# Flight Distance             -0.006         0.225   0.099               -
# Departure Delay in Minutes  -0.003        -0.004   -0.01           0.002
# Arrival Delay in Minutes      -0.0        -0.005  -0.012          -0.002
#
#                            Departure Delay in Minutes Arrival Delay in Minutes
# Gender                                          0.344                    0.899
# Customer Type                                   0.193                    0.127
# Age                                             0.001                    0.000
# Flight Distance                                 0.487                    0.435
# Departure Delay in Minutes                          -                       0.
# Arrival Delay in Minutes                        0.965                        -

# %%
#Een alternatieve methode
#De r en p waardes
data[['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']].rcorr(stars=False)
# Out:
#                                Age Flight Distance Departure Delay in Minutes  \
# Age                              -           0.000                      0.001
# Flight Distance              0.099               -                      0.487
# Departure Delay in Minutes   -0.01           0.002                          -
# Arrival Delay in Minutes    -0.012          -0.002                      0.965
#
#                            Arrival Delay in Minutes
# Age                                           0.000
# Flight Distance                               0.435
# Departure Delay in Minutes                       0.
# Arrival Delay in Minutes                          -

# %% [markdown]
# #### Maak een regressiemodel met Arrival Delay  als y (target value) en Flight Distance als x (feature matrix). Opnieuw Arrival Delay als afhankelijke variabel (target value) maar nu met behulp van Age en Departure Delay.

# %%
#De variabele Arrival Delay heeft missing values; die moeten er eerst uit
data.dropna(inplace=True)

# %%
#Voorspellen van Arrival Delay op basis van Flight Distance
lm = pg.linear_regression(data['Flight Distance'], data['Arrival Delay in Minutes'])
lm.round(2)
# Out:
#              names   coef    se      T  pval   r2  adj_r2  CI[2.5%]  CI[97.5%]
# 0        Intercept  15.29  0.19  81.71  0.00  0.0    -0.0     14.92      15.66
# 1  Flight Distance  -0.00  0.00  -0.78  0.43  0.0    -0.0     -0.00       0.00

# %%
lm = pg.linear_regression(data[['Flight Distance', 'Departure Delay in Minutes','Age']], data['Arrival Delay in Minutes'])
lm.round(2)
# Out:
#                         names  coef    se        T  pval    r2  adj_r2  \
# 0                   Intercept  1.11  0.09    11.88  0.00  0.93    0.93
# 1             Flight Distance -0.00  0.00    -5.01  0.00  0.93    0.93
# 2  Departure Delay in Minutes  0.98  0.00  1193.11  0.00  0.93    0.93
# 3                         Age -0.00  0.00    -2.39  0.02  0.93    0.93
#
#    CI[2.5%]  CI[97.5%]
# 0      0.92       1.29
# 1     -0.00      -0.00
# 2      0.98       0.98
# 3     -0.01      -0.00

# %%
#Nu met de z scores, dan zijn de coefficienten te vergelijken en onafhankelijk van de meeteenheid
data_z.dropna(inplace=True)
lm = pg.linear_regression(data_z[['Flight Distance', 'Departure Delay in Minutes','Age']], data_z['Arrival Delay in Minutes'])
lm.round(2)
# Out:
#                         names  coef   se        T  pval    r2  adj_r2  \
# 0                   Intercept  0.00  0.0     2.12  0.03  0.93    0.93
# 1             Flight Distance -0.00  0.0    -5.01  0.00  0.93    0.93
# 2  Departure Delay in Minutes  0.97  0.0  1193.11  0.00  0.93    0.93
# 3                         Age -0.00  0.0    -2.39  0.02  0.93    0.93
#
#    CI[2.5%]  CI[97.5%]
# 0      0.00       0.00
# 1     -0.01      -0.00
# 2      0.97       0.97
# 3     -0.00      -0.00

# %%
sns.regplot(x="Departure Delay in Minutes", y="Arrival Delay in Minutes", data=data)
# Out:
# <AxesSubplot:xlabel='Departure Delay in Minutes', ylabel='Arrival Delay in Minutes'>
