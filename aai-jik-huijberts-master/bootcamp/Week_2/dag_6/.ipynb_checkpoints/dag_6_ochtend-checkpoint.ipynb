# %% [markdown]
# ## Dag 6 ochtend

# %%
# imports
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from scipy.stats import norm
import scipy.stats as stats

# %% [markdown]
# Read the csv and save it as a variable

# %%
data = pd.read_csv("Airlinesatisfaction.csv")

# %% [markdown]
# Show data

# %%
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# Prepare data by removing the non sensical values

# %%
data = data.drop(columns = ["Unnamed: 0","id"])
data.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %% [markdown]
# Make the data easly readable

# %%
data['satisfaction'].replace({'neutral or dissatisfied': 0, 'satisfied': 1},inplace = True)
data['Gender'].replace({'Male': 0, 'Female': 1}, inplace = True)
data['Customer Type'].replace({'disloyal Customer': 0, 'Loyal Customer': 1}, inplace = True)
data['Type of Travel'].replace({'Personal Travel': 0, 'Business travel': 1}, inplace = True)
data['Class'].replace({'Eco': 1, 'Eco Plus': 2, 'Business':3}, inplace = True)

# %% [markdown]
# Create variables for the long texts

# %%
fd ="Flight Distance"
ddim = "Departure Delay in Minutes"
adim = "Arrival Delay in Minutes"

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ##### Histogrammen

# %%
'''Alle histogrammen bij elkaar (gebruik figzise anders is het niet leesbaar)'''
data.hist(bins = 20, figsize = (20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Gender'}>,
#         <AxesSubplot:title={'center':'Customer Type'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Type of Travel'}>,
#         <AxesSubplot:title={'center':'Class'}>],
#        [<AxesSubplot:title={'center':'Flight Distance'}>,
#         <AxesSubplot:title={'center':'Inflight wifi service'}>,
#         <AxesSubplot:title={'center':'Departure/Arrival time convenient'}>,
#         <AxesSubplot:title={'center':'Ease of Online booking'}>,
#         <AxesSubplot:title={'center':'Gate location'}>],
#        [<AxesSubplot:title={'center':'Food and drink'}>,
#         <AxesSubplot:title={'center':'Online boarding'}>,
#         <AxesSubplot:title={'center':'Seat comfort'}>,
#         <AxesSubplot:title={'center':'Inflight entertainment'}>,
#         <AxesSubplot:title={'center':'On-board service'}>],
#        [<AxesSubplot:title={'center':'Leg room service'}>,
# ...

# %% [markdown]
# ##### Boxplots

# %%
sns.boxplot(x=data["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x=data['Flight Distance'])
# Out:
# <AxesSubplot:xlabel='Flight Distance'>

# %%
sns.boxplot(x=data['Departure Delay in Minutes'])
# Out:
# <AxesSubplot:xlabel='Departure Delay in Minutes'>

# %%
sns.boxplot(x=data['Arrival Delay in Minutes'])
# Out:
# <AxesSubplot:xlabel='Arrival Delay in Minutes'>

# %% [markdown]
# #####  Test  normaalverdeling

# %%
from scipy.stats import kstest, norm
def print_kstest(val):
    ks_stats, p_value = kstest(data[val], "norm")
    print("ks result: " + str(ks_stats) + " P value: " +  str(p_value))

# %% [markdown]
# Test age

# %%
print_kstest("Age")
# Out:
# ks result: 0.9999999999987201 P value: 0.0

# %% [markdown]
# Test flight distance

# %%
print_kstest(fd)
# Out:
# ks result: 1.0 P value: 0.0

# %% [markdown]
# Test Departure Delay in Minutes

# %%
print_kstest(ddim)
# Out:
# ks result: 0.5 P value: 0.0

# %% [markdown]
# Test Arrival Delay in Minutes

# %%
print_kstest(adim)
# Out:
# ks result: nan P value: nan

# %% [markdown]
# ##### Get Z indexes

# %% [markdown]
# Scaler kan de data naar een z-index veranderen.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
z_data = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)

# %% [markdown]
# ##### Heatmap and scatter matrix

# %% [markdown]
# Met een heatmap kan je makkelijk de correlatie van bepaalde waarden aflezen.

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(data.corr(), annot = True, square = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Heatmap z-scores

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(z_data.corr(), annot = True, square = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Scatter matrix

# %% [markdown]
# Een scatter matrix laat de verspreiding van de data goed zien. Dit kan gecombineerd worden met een andere column om te kijken of er een relatie tussen de data is.

# %%
scatter_matrix(data[["Age",fd,adim,ddim]], figsize = (12, 8))
plt.show()

# %%
scatter_matrix(z_data[["Age",fd,adim,ddim]], figsize = (12, 8))
plt.show()
